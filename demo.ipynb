# %% [markdown]
# <a href="https://colab.research.google.com/github/itsPronay/Benchmark-vit-tinys/blob/main/demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf Benchmark-vit-tinys

# %%
# !git clone https://github.com/itsPronay/Benchmark-vit-tinys.git
# Out:
# Cloning into 'Benchmark-vit-tinys'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 56 (delta 17), reused 55 (delta 16), pack-reused 0 (from 0)
# Receiving objects: 100% (56/56), 28.17 KiB | 14.09 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
# !pip3 install qai-hub
# !qai-hub configure --api_token znlq94irgqllstitbp39jzkdvvkk7cmu6lrcjy33
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.3/85.3 kB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 106.9 MB/s eta 0:00:00
# ...
# 2026-03-19 19:14:41.649 - INFO - Enabling verbose logging.
# qai-hub configuration saved to /root/.qai_hub/client.ini
# ==================== /root/.qai_hub/client.ini ====================
# [api]
# api_token = znlq94irgqllstitbp39jzkdvvkk7cmu6lrcjy33
# api_url = https://workbench.aihub.qualcomm.com
# web_url = https://workbench.aihub.qualcomm.com
# verbose = True

# %%
# !pip install wandb
import wandb
wandb.login()
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: itspronay (itspronay-southeast-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !python /content/Benchmark-vit-tinys/run.py
# Out:
# Running benchmark for Model: vit_tiny_patch16_224 and Image Size: 224
# Created model vit_tiny_patch16_224 with img_size=224
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: itspronay (itspronay-southeast-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: ⢿ Waiting for wandb.init()...
# wandb: ⣻ setting up run 0ny1zxmf (0.2s)
# wandb: ⣽ setting up run 0ny1zxmf (0.2s)
# wandb: ⣾ setting up run 0ny1zxmf (0.2s)
# wandb: ⣷ setting up run 0ny1zxmf (0.2s)
# wandb: ⣯ setting up run 0ny1zxmf (0.2s)
# wandb: ⣟ setting up run 0ny1zxmf (0.7s)
# wandb: ⡿ setting up run 0ny1zxmf (0.7s)
# wandb: ⢿ setting up run 0ny1zxmf (0.7s)
# wandb: ⣻ setting up run 0ny1zxmf (0.7s)
# wandb: Tracking run with wandb version 0.25.1
# wandb: Run data is saved locally in /content/wandb/run-20260319_193939-0ny1zxmf
# wandb: Run `wandb offline` to turn off syncing.
# ...
